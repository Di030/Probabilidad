# %% [markdown]
# #Practica 4
# ##Alumno: Reyes Gutiérrez Diego
# ##Facilitador:    José Gabriel Rodríguez Rivas

# %%
#Libreria de python para generar numeros reales aleatrorios
import random
#Libreria de python para graficar
import matplotlib.pyplot as plt
from statistics import*
#Libreria de dataframe
import pandas as pd
#Libreria de funciones matemáticas
import math

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio = round (random.uniform(50,100), 2)
  fabrica1.append(numero_aleatorio)
print (fabrica1)
# Out:
# [76.53, 95.16, 64.01, 57.04, 84.64, 62.68, 74.54, 90.16, 88.85, 53.15, 74.79, 74.71, 59.12, 55.03, 79.23, 62.33, 82.8, 63.04, 65.11, 82.7, 63.6, 73.63, 62.19, 75.9, 94.61, 97.71, 53.12, 74.67, 87.94, 74.87, 74.41, 81.68, 91.46, 84.48, 59.58, 58.44, 58.21, 76.8, 89.14, 54.09, 73.03, 59.33, 85.9, 69.09, 80.77, 88.08, 64.31, 59.66, 98.84, 93.56, 72.83, 53.88, 62.68, 83.23, 69.63, 95.65, 72.65, 79.07, 67.67, 85.61, 92.16, 51.64, 65.06, 94.13, 85.08, 77.4, 94.02, 54.65, 81.32, 50.05, 97.39, 64.82, 50.61, 54.8, 92.82, 72.88, 75.94, 67.19, 58.11, 63.12, 69.89, 58.35, 51.78, 70.24, 95.84, 72.95, 87.59, 86.59, 64.34, 92.29, 78.32, 75.22, 68.27, 90.75, 92.87, 94.73, 53.19, 55.75, 96.8, 75.53]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio2 = round (random.uniform(50,100), 2)
  fabrica2.append(numero_aleatorio2)
print (fabrica2)
# Out:
# [53.77, 76.69, 71.69, 96.81, 87.83, 69.65, 67.58, 66.86, 76.39, 50.84, 69.41, 80.89, 70.65, 64.43, 77.62, 66.09, 81.81, 75.45, 50.66, 86.91, 78.72, 74.4, 86.13, 91.11, 65.83, 78.9, 96.46, 52.6, 50.42, 94.92, 54.93, 89.73, 86.58, 98.82, 91.67, 94.73, 91.64, 75.39, 72.66, 65.84, 53.99, 89.39, 64.16, 60.19, 79.56, 83.69, 56.92, 88.19, 87.41, 70.78, 68.32, 92.93, 87.05, 61.7, 93.7, 96.64, 83.48, 50.29, 96.24, 71.53, 76.76, 51.99, 64.74, 85.18, 76.12, 87.8, 72.42, 58.11, 75.5, 74.62, 62.42, 99.46, 71.39, 91.33, 81.36, 98.85, 95.01, 76.88, 80.35, 96.67, 57.31, 94.42, 89.63, 62.25, 84.2, 79.37, 76.98, 98.42, 58.02, 74.6, 97.91, 93.1, 58.06, 95.8, 93.64, 54.41, 66.22, 57.9, 99.4, 99.72]

# %%
plt.hist(fabrica1)
plt.title("Producción diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Producción diaria de la fabrica 2")
# Out:
# Text(0.5, 1.0, 'Producción diaria de la fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("valores de la fabrica 1")
print("La media es: ",media1)
print("la moda es: ",moda1)
print("La mediana es: ", mediana1)
# Out:
# valores de la fabrica 1
# La media es:  74.221
# la moda es:  62.68
# La mediana es:  74.605

# %%
media = mean(fabrica2)
mediana=median(fabrica2)
moda=mode(fabrica2)
print("valores de la fabrica 2")
print("La media es: ",media)
print("la moda es: ",moda)
print("La mediana es: ", mediana)
# Out:
# valores de la fabrica 2
# La media es:  77.3799
# la moda es:  53.77
# La mediana es:  76.93

# %%
#generar sublot de un renglon por dos columnas
fig,(ax1, ax2)= plt.subplots(nrows=1,ncols=2, figsize=(10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
#valor minimo, valor maximo y el rango

# %%
plt.hist(fabrica1, bins=20, alpha = 0.2, color='blue', edgecolor='black')
plt.axvline(media1, color='r', linestyle='dashed', linewidth=2,label='Media')
plt.axvline(mediana1, color='purple', linestyle='dashed', linewidth=2,label='Mediana')
plt.axvline(moda1, color='g', linestyle='dashed', linewidth=2,label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=20, alpha =0.2, color='blue', edgecolor='black')
plt.axvline(media, color='r', linestyle='dashed', linewidth=2, label=('Media'))
plt.axvline(mediana, color='purple', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda, color='g', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ### Maximo, minimo y rango

# %%
maximo = max (fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media1 = mean (fabrica1)
mediana1= median(fabrica1)
moda1= mode(fabrica1)
print("estadisticas de la fabrica 1: maximo", maximo," minimo", minimo," rango", rango," media", media1, " mediana", mediana1," moda", moda1)
# Out:
# estadisticas de la fabrica 1: maximo 98.84  minimo 50.05  rango 48.790000000000006  media 74.221  mediana 74.605  moda 62.68

# %%
maximo = max (fabrica2)
minimo = min(fabrica2)
rango = maximo - minimo
media = mean (fabrica2)
mediana= median(fabrica2)
moda= mode(fabrica2)
print("estadisticas de la fabrica 1: maximo", maximo,"\n minimo", minimo," \nrango", rango," \nmedia", media, " \n mediana", mediana," \n moda", moda)
# Out:
# estadisticas de la fabrica 1: maximo 99.72
#  minimo 50.29
# rango 49.43
# media 77.3799
#  mediana 76.93
#  moda 53.77

# %% [markdown]
# ###Dispersion de datos

# %%
Desviacionestandar_fabrica1=stdev(fabrica1)
print("La desviacion estandar de la fabrica 1 es: ",Desviacionestandar_fabrica1)
# Out:
# La desviacion estandar de la fabrica 1 es:  14.072657312618105

# %%
Desviacionestandar_fabrica2=stdev(fabrica2)
print("La desviacion estandar de la fabrica 2 es: ",Desviacionestandar_fabrica2)
# Out:
# La desviacion estandar de la fabrica 2 es:  14.646048696291482

# %%
plt.figure(figsize=(11,8))
plt.hist(fabrica1, bins=20, alpha = 0.2, color='blue', edgecolor='black')
plt.axvline(media1, color='r', linestyle='dashed', linewidth=2,label='Media')
plt.axvline(mediana1, color='purple', linestyle='dashed', linewidth=2,label='Mediana')
plt.axvline(moda1, color='g', linestyle='dashed', linewidth=2,label='Moda')
plt.axvline(media1 - Desviacionestandar_fabrica1, color='y', linestyle='dashed', linewidth=2,label=f'Desviacion estandar={Desviacionestandar_fabrica1:.2f}')
plt.axvline(media1 + Desviacionestandar_fabrica1, color='y', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(11,8))
plt.hist(fabrica2, bins=20, alpha = 0.2, color='blue', edgecolor='black')
plt.axvline(media, color='r', linestyle='dashed', linewidth=2,label='Media')
plt.axvline(mediana, color='purple', linestyle='dashed', linewidth=2,label='Mediana')
plt.axvline(moda, color='g', linestyle='dashed', linewidth=2,label='Moda')
plt.axvline(media - Desviacionestandar_fabrica1, color='y', linestyle='dashed', linewidth=2,label=f'Desviacion estandar={Desviacionestandar_fabrica1:.2f}')
plt.axvline(media + Desviacionestandar_fabrica1, color='y', linestyle='dashed', linewidth=2)
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# #Tablas de frecuencias

# %%
edades=[]
for i in range (100):
  num_aleatorio=random.randint(18,70)
  edades.append(num_aleatorio)
print(edades)
# Out:
# [69, 66, 28, 39, 23, 34, 68, 19, 20, 65, 45, 44, 25, 21, 58, 32, 37, 39, 57, 21, 33, 59, 57, 47, 67, 41, 53, 44, 59, 48, 50, 32, 51, 69, 41, 56, 31, 63, 19, 56, 47, 61, 61, 51, 40, 56, 68, 65, 64, 33, 56, 54, 65, 59, 18, 61, 49, 52, 56, 52, 62, 46, 57, 68, 31, 65, 42, 51, 34, 63, 55, 57, 32, 47, 65, 37, 63, 32, 36, 28, 40, 27, 45, 36, 23, 66, 61, 55, 33, 43, 36, 21, 35, 48, 69, 67, 22, 67, 56, 43]

# %%
df_edades= pd.DataFrame(edades, columns=["edades"])
df_edades
# Out:
#     edades
# 0       69
# 1       66
# 2       28
# 3       39
# 4       23
# ..     ...
# 95      67
# 96      22
# 97      67
# 98      56
# 99      43
#
# [100 rows x 1 columns]

# %%
tabla_frecuencias=df_edades['edades'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by = "Edad")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 38    18           1
# 25    19           2
# 44    20           1
# 6     21           3
# 45    22           1
# 20    23           2
# 43    25           1
# 33    27           1
# 17    28           2
# 19    31           2
# 4     32           4
# 13    33           3
# 21    34           2
# 34    35           1
# 9     36           3
# 29    37           2
# 18    39           2
# 16    40           2
# 24    41           2
# 31    42           1
# 22    43           2
# 28    44           2
# 26    45           2
# 32    46           1
# 11    47           3
# 15    48           2
# 37    49           1
# 41    50           1
# 8     51           3
# 27    52           2
# 36    53           1
# 39    54           1
# 30    55           2
# 0     56           6
# 3     57           4
# 42    58           1
# 12    59           3
# 2     61           4
# 35    62           1
# 7     63           3
# 40    64           1
# 1     65           5
# 23    66           2
# 10    67           3
# 14    68           3
# 5     69           3

# %%
tabla_frecuencias["Frec.Relativa"]=tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec.Relativa
# 38    18           1           0.01
# 25    19           2           0.02
# 44    20           1           0.01
# 6     21           3           0.03
# 45    22           1           0.01
# 20    23           2           0.02
# 43    25           1           0.01
# 33    27           1           0.01
# 17    28           2           0.02
# 19    31           2           0.02
# 4     32           4           0.04
# 13    33           3           0.03
# 21    34           2           0.02
# 34    35           1           0.01
# 9     36           3           0.03
# 29    37           2           0.02
# 18    39           2           0.02
# 16    40           2           0.02
# 24    41           2           0.02
# 31    42           1           0.01
# 22    43           2           0.02
# 28    44           2           0.02
# 26    45           2           0.02
# 32    46           1           0.01
# 11    47           3           0.03
# 15    48           2           0.02
# 37    49           1           0.01
# 41    50           1           0.01
# 8     51           3           0.03
# 27    52           2           0.02
# 36    53           1           0.01
# 39    54           1           0.01
# 30    55           2           0.02
# 0     56           6           0.06
# 3     57           4           0.04
# 42    58           1           0.01
# 12    59           3           0.03
# 2     61           4           0.04
# 35    62           1           0.01
# 7     63           3           0.03
# 40    64           1           0.01
# 1     65           5           0.05
# 23    66           2           0.02
# 10    67           3           0.03
# 14    68           3           0.03
# 5     69           3           0.03

# %%
tabla_frecuencias["frec.porcentual"]=tabla_frecuencias["Frecuencia"]/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec.Relativa  frec.porcentual
# 38    18           1           0.01              1.0
# 25    19           2           0.02              2.0
# 44    20           1           0.01              1.0
# 6     21           3           0.03              3.0
# 45    22           1           0.01              1.0
# 20    23           2           0.02              2.0
# 43    25           1           0.01              1.0
# 33    27           1           0.01              1.0
# 17    28           2           0.02              2.0
# 19    31           2           0.02              2.0
# 4     32           4           0.04              4.0
# 13    33           3           0.03              3.0
# 21    34           2           0.02              2.0
# 34    35           1           0.01              1.0
# 9     36           3           0.03              3.0
# 29    37           2           0.02              2.0
# 18    39           2           0.02              2.0
# 16    40           2           0.02              2.0
# 24    41           2           0.02              2.0
# 31    42           1           0.01              1.0
# 22    43           2           0.02              2.0
# 28    44           2           0.02              2.0
# 26    45           2           0.02              2.0
# 32    46           1           0.01              1.0
# 11    47           3           0.03              3.0
# 15    48           2           0.02              2.0
# 37    49           1           0.01              1.0
# 41    50           1           0.01              1.0
# 8     51           3           0.03              3.0
# 27    52           2           0.02              2.0
# 36    53           1           0.01              1.0
# 39    54           1           0.01              1.0
# 30    55           2           0.02              2.0
# 0     56           6           0.06              6.0
# 3     57           4           0.04              4.0
# 42    58           1           0.01              1.0
# 12    59           3           0.03              3.0
# 2     61           4           0.04              4.0
# 35    62           1           0.01              1.0
# 7     63           3           0.03              3.0
# 40    64           1           0.01              1.0
# 1     65           5           0.05              5.0
# 23    66           2           0.02              2.0
# 10    67           3           0.03              3.0
# 14    68           3           0.03              3.0
# 5     69           3           0.03              3.0

# %%
tabla_frecuencias["Frecuencia acumulada"]=tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec.Relativa  frec.porcentual  Frecuencia acumulada
# 38    18           1           0.01              1.0                     1
# 25    19           2           0.02              2.0                     3
# 44    20           1           0.01              1.0                     4
# 6     21           3           0.03              3.0                     7
# 45    22           1           0.01              1.0                     8
# 20    23           2           0.02              2.0                    10
# 43    25           1           0.01              1.0                    11
# 33    27           1           0.01              1.0                    12
# 17    28           2           0.02              2.0                    14
# 19    31           2           0.02              2.0                    16
# 4     32           4           0.04              4.0                    20
# 13    33           3           0.03              3.0                    23
# 21    34           2           0.02              2.0                    25
# 34    35           1           0.01              1.0                    26
# 9     36           3           0.03              3.0                    29
# 29    37           2           0.02              2.0                    31
# 18    39           2           0.02              2.0                    33
# 16    40           2           0.02              2.0                    35
# 24    41           2           0.02              2.0                    37
# 31    42           1           0.01              1.0                    38
# 22    43           2           0.02              2.0                    40
# 28    44           2           0.02              2.0                    42
# 26    45           2           0.02              2.0                    44
# 32    46           1           0.01              1.0                    45
# 11    47           3           0.03              3.0                    48
# 15    48           2           0.02              2.0                    50
# 37    49           1           0.01              1.0                    51
# 41    50           1           0.01              1.0                    52
# 8     51           3           0.03              3.0                    55
# 27    52           2           0.02              2.0                    57
# 36    53           1           0.01              1.0                    58
# 39    54           1           0.01              1.0                    59
# 30    55           2           0.02              2.0                    61
# 0     56           6           0.06              6.0                    67
# 3     57           4           0.04              4.0                    71
# 42    58           1           0.01              1.0                    72
# 12    59           3           0.03              3.0                    75
# 2     61           4           0.04              4.0                    79
# 35    62           1           0.01              1.0                    80
# 7     63           3           0.03              3.0                    83
# 40    64           1           0.01              1.0                    84
# 1     65           5           0.05              5.0                    89
# 23    66           2           0.02              2.0                    91
# 10    67           3           0.03              3.0                    94
# 14    68           3           0.03              3.0                    97
# 5     69           3           0.03              3.0                   100

# %% [markdown]
# #Regla de sturges
# 1.- Es una regla que sirve para calucular el numero de clases o intervalos idóneo, en los que se debe de dividir un conjunto de datos
#
# $
# c=1+ log_2(N)
# $

# %%
print(edades)
# Out:
# [69, 66, 28, 39, 23, 34, 68, 19, 20, 65, 45, 44, 25, 21, 58, 32, 37, 39, 57, 21, 33, 59, 57, 47, 67, 41, 53, 44, 59, 48, 50, 32, 51, 69, 41, 56, 31, 63, 19, 56, 47, 61, 61, 51, 40, 56, 68, 65, 64, 33, 56, 54, 65, 59, 18, 61, 49, 52, 56, 52, 62, 46, 57, 68, 31, 65, 42, 51, 34, 63, 55, 57, 32, 47, 65, 37, 63, 32, 36, 28, 40, 27, 45, 36, 23, 66, 61, 55, 33, 43, 36, 21, 35, 48, 69, 67, 22, 67, 56, 43]

# %%
plt.hist(edades, alpha=0.5, rwidth=0.95)
plt.title("Histograma de edades basado en valores estandar de matplotlib")
plt.xlabel("edades")
plt.ylabel("Frecuencias")
# Out:
# Text(0, 0.5, 'Frecuencias')

# %%
df_edades_sturges = pd.DataFrame({"Edad": edades})
df_edades_sturges
# Out:
#     Edad
# 0     69
# 1     66
# 2     28
# 3     39
# 4     23
# ..   ...
# 95    67
# 96    22
# 97    67
# 98    56
# 99    43
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1+math.log2(n))
print("el valor de n= ",n," valor de num de intervalos= ", k)
# Out:
# el valor de n=  100  valor de num de intervalos=  7

# %%
tabla_frec_sturges = pd.cut(df_edades_sturges['Edad'], bins=k).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  Edad
# 0    (61.714, 69.0]    21
# 1  (54.429, 61.714]    20
# 2  (39.857, 47.143]    15
# 3  (32.571, 39.857]    13
# 4  (17.949, 25.286]    11
# 5  (47.143, 54.429]    11
# 6  (25.286, 32.571]     9

# %%
tabla_frec_sturges.columns=['Clase','Frecuencia']
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0    (61.714, 69.0]          21
# 1  (54.429, 61.714]          20
# 2  (39.857, 47.143]          15
# 3  (32.571, 39.857]          13
# 4  (17.949, 25.286]          11
# 5  (47.143, 54.429]          11
# 6  (25.286, 32.571]           9

# %%
tabla_frec_sturges=tabla_frec_sturges.sort_values(by ='Clase')
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 4  (17.949, 25.286]          11
# 6  (25.286, 32.571]           9
# 3  (32.571, 39.857]          13
# 2  (39.857, 47.143]          15
# 5  (47.143, 54.429]          11
# 1  (54.429, 61.714]          20
# 0    (61.714, 69.0]          21

# %%
tabla_frec_sturges['Frec.relativa']=tabla_frec_sturges['Frecuencia']/n
tabla_frec_sturges['Frec.porcentual']=tabla_frec_sturges['Frecuencia']/n*100
tabla_frec_sturges['Frec.acumulada']=tabla_frec_sturges['Frecuencia'].cumsum()
tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec.relativa  Frec.porcentual  \
# 4  (17.949, 25.286]          11           0.11             11.0
# 6  (25.286, 32.571]           9           0.09              9.0
# 3  (32.571, 39.857]          13           0.13             13.0
# 2  (39.857, 47.143]          15           0.15             15.0
# 5  (47.143, 54.429]          11           0.11             11.0
# 1  (54.429, 61.714]          20           0.20             20.0
# 0    (61.714, 69.0]          21           0.21             21.0
#
#    Frec.acumulada
# 4              11
# 6              20
# 3              33
# 2              48
# 5              59
# 1              79
# 0             100

# %%
plt.hist(df_edades_sturges['Edad'], bins=k, alpha=0.5,rwidth=0.95)
plt.title("Histograma basado en la regla de Sturges")
plt.xlabel("edades")
plt.ylabel("Frecuencias")
# Out:
# Text(0, 0.5, 'Frecuencias')
